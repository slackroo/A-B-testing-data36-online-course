# %% [markdown]
# # import, preparation

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
# %config Completer.use_jedi = False

# %%
# !ls
# !echo ----
# !cd ..
# !pwd
# Out:
# Untitled.ipynb	 Untitled4.ipynb	     data36_popup_analysis.ipynb
# Untitled1.ipynb  best_bet.ipynb		     yahoo_finance.ipynb
# Untitled2.ipynb  coinbase_api_example.ipynb
# Untitled3.ipynb  data36_popup.ipynb
# ----
# /home/slackroo/JDS/data_practice/API_practice

# %% [markdown]
# # 1. opening files

# %%
#each and every pageview in a log
pageviews = pd.read_csv('/home/slackroo/JDS/data_practice/pageviews.tsv', sep='\t',
            names = ['date', 'time', 'country', 'user_id', 'event', 'source', 'page', 'width', 'hight'])

# %%
pageviews.head(5)
# Out:
#          date          time country   user_id            event  \
# 0  2021-02-01  00:00:19.679      MY  u8515925  b'pageview_blog
# 1  2021-02-01  00:00:31.810      US  u8544901  b'pageview_blog
# 2  2021-02-01  00:00:57.138     NaN  u8535534  b'pageview_blog
# 3  2021-02-01  00:01:30.771      MY  u8594125  b'pageview_blog
# 4  2021-02-01  00:02:31.284     NaN  u8564427  b'pageview_blog
#
#                     source                                               page  \
# 0                      NaN  https://data36.com/pandas-tutorial-1-basics-re...
# 1   https://www.google.com  https://data36.com/python-nested-loops-if-stat...
# 2   https://www.google.com                https://data36.com/funnel-analysis/
# 3  https://www.google.com/  https://data36.com/how-to-import-data-into-sql...
# 4  https://www.google.com/  https://data36.com/statistical-bias-types-expl...
#
#    width  hight
# 0   1536    864
# 1   1440    900
# 2    375    812
# 3   1920   1080
# 4   1440    900

# %%
#each and every newsletter subscription in a log
newsletters = pd.read_csv('/home/slackroo/JDS/data_practice/newsletter.tsv', sep='\t',
            names = ['date', 'time', 'country', 'user_id', 'event', 'button', 'page', 'width', 'hight'])

# %%
#each and every click on the JDS site in a log
jds = pd.read_csv('/home/slackroo/JDS/data_practice/jds_site_click.tsv', sep='\t',
            names = ['date', 'time', 'country', 'user_id1', 'event', 'button', 'page', 'width', 'hight'])

# %% [markdown]
# # 2. data discovery

# %% [markdown]
# ### toplist of visited pages

# %%
pageview_count = pageviews.groupby('page').count().sort_values(by='date', ascending=False)
pageview_count.head(80)[['date']]
# Out:
#                                                      date
# page
# https://data36.com/python-nested-loops-if-state...  23634
# https://data36.com/plot-histogram-python-pandas/    22262
# https://data36.com/sql-interview-questions-tech...  19844
# https://data36.com/pandas-tutorial-2-aggregatio...  18238
# https://data36.com/how-to-import-data-into-sql-...  14367
# https://data36.com/sql-functions-beginners-tuto...  12272
# https://data36.com/linear-regression-in-python-...  11913
# https://data36.com/statistical-bias-types-expla...  11808
# https://data36.com/pandas-tutorial-1-basics-rea...  11278
# https://data36.com/create-table-sql/                10480
# https://data36.com/best-computer-laptop-for-a-d...  10450
# https://data36.com/scatter-plot-pandas-matplotlib/   9988
# https://data36.com/                                  9364
# https://data36.com/python-built-in-functions-me...   8402
# https://data36.com/sql-current-date-time/            7796
# https://data36.com/learning-data-science/            5956
# https://data36.com/statistical-bias-types-examp...   4766
# https://data36.com/statistical-averages-mean-me...   4256
# https://data36.com/install-sql-workbench-postgr...   4143
# https://data36.com/the-junior-data-scientists-f...   3901
# https://data36.com/python-libraries-packages-da...   3686
# https://data36.com/statistical-significance-in-...   3259
# https://data36.com/python-if-statements-explain...   2886
# https://data36.com/data-coding-101-install-pyth...   2822
# https://data36.com/scraping-multiple-web-pages-...   2809
# https://data36.com/python-for-loops-explained-d...   2753
# https://data36.com/sublime-text-data-science-re...   2579
# https://data36.com/how-to-become-a-data-scientist/   2422
# https://data36.com/learn-sql-for-data-analysis-...   2404
# https://data36.com/web-scraping-tutorial-episod...   2230
# https://data36.com/sql-for-data-analysis-tutori...   2121
# https://data36.com/data-science-career-question-1/   2090
# https://data36.com/variables-if-statements-whil...   2050
# https://data36.com/learn-python-for-data-scienc...   1990
# https://data36.com/expected-value-formula/           1954
# https://data36.com/sql-best-practices-data-anal...   1930
# https://data36.com/funnel-analysis/                  1580
# https://data36.com/python-for-data-science-pyth...   1555
# https://data36.com/sql-for-aspiring-data-scient...   1350
# https://data36.com/inner-circle-data36-newslett...   1299
# https://data36.com/how-to-run-python-script/         1255
# https://data36.com/pandas-tutorial-3-important-...   1254
# https://data36.com/category/coding-data-science...   1212
# https://data36.com/what-is-data-science/             1152
# https://data36.com/computer-setup-data-science/      1126
# https://data36.com/tag/python/                       1100
# https://data36.com/connect-google-data-studio-p...   1098
# https://data36.com/fake-door-testing/                1006
# https://data36.com/learn-data-analytics-bash-sc...    959
# https://data36.com/data-team-structure-data-org...    943
# https://data36.com/sql-data-analysis-advanced-t...    930
# https://data36.com/predictive-analytics-101-par...    915
# https://data36.com/python-data-structures-data-...    892
# https://data36.com/predictive-analytics-101-par...    883
# https://data36.com/thank-you-for-subscribing/         882
# https://data36.com/data-science-projects-for-bo...    870
# https://data36.com/junior-data-scientist-akademia/    867
# https://data36.com/presentation-tips-for-data-p...    727
# https://data36.com/upload-dataset-to-a-server-c...    718
# https://data36.com/how-to-become-a-data-scienti...    702
# https://data36.com/beautiful-soup-tutorial-web-...    698
# https://data36.com/statistical-variability-stan...    694
# https://data36.com/author/mestitomi/                  678
# https://data36.com/tomi-mester/                       678
# https://data36.com/data-science-cv-resume-cover...    661
# https://data36.com/five-second-testing/               657
# https://data36.com/sql-where-clause-tutorial-be...    649
# https://data36.com/data-science-freelancing-tips/     626
# https://data36.com/bevezetes-data-science-vilag...    624
# https://data36.com/python-import-built-in-modul...    606
# https://data36.com/python-syntax-essentials-and...    571
# https://data36.com/tag/sql/                           565
# https://data36.com/sql-join-data-analysis-tutor...    561
# https://data36.com/kevin-bacon-game-recursive-sql/    555
# https://data36.com/data-coding-101-introduction...    546
# https://data36.com/become-data-scientist-7-plus...    544
# https://data36.com/tag/data-science/                  538
# https://data36.com/data-analytics-basics-intro/       489
# https://data36.com/customer-retention-analysis-...    479
# https://data36.com/data36-inner-circle-subscrip...    466

# %%
#the same thing on a bar chart
pageview_count.head(10)[['date']].plot.bar()

# %%
#saving top pages into a Python list for later
#top_pages = list(pageview_count.head(20).index)

# %% [markdown]
# ### toplist: on which pages do people subscribe

# %% [markdown]
# ##### Newsletter subscriptions gives interested users

# %%
newsletters.groupby('page').count()[['date']].sort_values(by='date',ascending = False).head(10)
# Out:
#                                                     date
# page
# https://data36.com/how-to-become-a-data-scientist/   676
# https://data36.com/sql-interview-questions-tech...   543
# https://data36.com/inner-circle-data36-newslett...   499
# https://data36.com/learn-sql-for-data-analysis-...    43
# https://data36.com/learn-python-for-data-scienc...    41
# https://data36.com/sql-for-data-analysis-tutori...    35
# https://data36.com/python-for-data-science-pyth...    32
# https://data36.com/how-to-import-data-into-sql-...    27
# https://data36.com/python-built-in-functions-me...    26
# https://data36.com/python-nested-loops-if-state...    22

# %%
#same thing on a bar chart
newsletters.groupby('page').count()[['date']].sort_values(by='date', ascending = False).head(10).plot.bar()

# %% [markdown]
# ## Finding where people come in for the main course selling pages

# %%
jds_sources = pageviews[pageviews.page == 'https://data36.com/the-junior-data-scientists-first-month-online-course/']
sql_sources = pageviews[pageviews.page == 'https://data36.com/sql-for-aspiring-data-scientists-7-day-online-course/']
htb_sources = pageviews[pageviews.page == 'https://data36.com/how-to-become-a-data-scientist/']

# %%
jds_sources.groupby('source').count()[['date']].sort_values(by='date', ascending = False).head(10).plot.bar()

# %%
sql_sources.groupby('source').count()[['date']].sort_values(by='date', ascending = False).head(10).plot.bar()

# %%
htb_sources.groupby('source').count()[['date']].sort_values(by='date', ascending = False).head(10).plot.bar()

# %% [markdown]
# ### error! click through rate in most read articles

# %%
page = 'https://data36.com/learning-data-science/'
print(pageviews[pageviews.page == page].count().date)
newsletters[newsletters.page == page].date.count()
# Out:
# 5956
# 3

# %%
pages = ['https://data36.com/learning-data-science/',
        'https://data36.com/become-data-scientist-7-plus-1-selfish-reasons/',
        'https://data36.com/data-science-career-question-1/',
        'https://data36.com/presentation-tips-for-data-professionals/']

for i in pages:
    page = i
    print((pageviews[pageviews.page == page].count().date), newsletters[newsletters.page == page].date.count())
# Out:
# 5956 3
# 544 0
# 2090 1
# 727 0

# %% [markdown]
# #### conclusion: the conversion rate of the popup is terrible!

# %% [markdown]
# # 3. DEFINING CONVERSION EVENTS

# %% [markdown]
# ### how to become a DS micro conversion

# %%
howto_visited = pageviews[pageviews.page == 'https://data36.com/how-to-become-a-data-scientist/']
howto_visited = howto_visited.drop_duplicates('user_id', keep='last').groupby('source').count()
howto_visited = howto_visited[howto_visited.date > 5]
howto_visited = howto_visited.reset_index()[['source','date']]

# %% [markdown]
# ### how to become a DS macro conversion

# %%
howto_converted = newsletters[newsletters.page == 'https://data36.com/how-to-become-a-data-scientist/'][[
    'user_id', 'date', 'time']]
howto_converted = howto_converted.drop_duplicates('user_id')

# %%
howto_converted
# Out:
#        user_id        date          time
# 0     u8446607  2021-02-01  02:35:44.972
# 12    u8528818  2021-02-01  12:29:09.329
# 13    u8440763  2021-02-01  12:56:49.099
# 18    u8572725  2021-02-01  14:23:07.309
# 23    u8430160  2021-02-01  20:50:30.942
# ...        ...         ...           ...
# 2133  u8554835  2021-04-29  14:26:12.328
# 2138  u8603988  2021-04-29  16:23:22.549
# 2142  u8601163  2021-04-30  08:51:38.771
# 2150  u8496510  2021-04-30  15:31:07.538
# 2155  u8420346  2021-04-30  18:50:06.163
#
# [411 rows x 3 columns]

# %% [markdown]
# ### JDS micro conversion

# %%
jds_visited = pageviews[pageviews.page == 'https://data36.com/the-junior-data-scientists-first-month-online-course/']
jds_visited = jds_visited.drop_duplicates('user_id', keep='last').groupby('source').count()
jds_visited = jds_visited[jds_visited.date > 5]
jds_visited = jds_visited.reset_index()[['source','date']]

# %% [markdown]
# ### JDS macro conversion

# %%
jds_converted = jds[jds.button == "Subscribe!"][['user_id1', 'date', 'time']].drop_duplicates('user_id1')

# %% [markdown]
# # JDS vs HOWTO converted people

# %% [markdown]
# ### is there an overlap? how big?

# %%
howto_converted.count()
# Out:
# user_id    411
# date       411
# time       411
# dtype: int64

# %%
jds_converted.count()
# Out:
# user_id1    216
# date        216
# time        216
# dtype: int64

# %% [markdown]
# ### how many people joined both JDS and how to

# %%
jds_converted.merge(howto_converted, left_on = 'user_id1', right_on = 'user_id', how = 'inner').count()
# Out:
# user_id1    42
# date_x      42
# time_x      42
# user_id     42
# date_y      42
# time_y      42
# dtype: int64

# %% [markdown]
# #### hypothesis #1 is disproven!!!

# %% [markdown]
# # 4. CREATING A "SUPER TABLE" WITH: VISITS, MICRO- & MACRO-CONVERSIONS

# %% [markdown]
# ### this is the tricky part -- creating last click attribution

# %%
#merging the visited pages to the macro conversion event
howto_converted_source = howto_converted.merge(pageviews, left_on = 'user_id', right_on = 'user_id', how = 'inner')

# %%
#filtering for only those events that happened BEFORE the actual conversion
howto_converted_source = howto_converted_source[
    (howto_converted_source.time_x > howto_converted_source.time_y) & (
        howto_converted_source.date_x == howto_converted_source.date_y)]

# %%
#filtering for the LAST event before the conversion, remove duplicates, group, count, etc.
howto_converted_source = howto_converted_source[
    howto_converted_source.page == 'https://data36.com/how-to-become-a-data-scientist/'
                  ].drop_duplicates('user_id', keep='last').groupby('source').count()[['date_x']].sort_values(
    by='date_x', ascending = False)

# %%
#formatting
howto_converted_source = howto_converted_source.reset_index()

# %%
###this is the list of the last articles people visited before coming
###to the https://data36.com/how-to-become-a-data-scientist/ and actually subscribe.

howto_converted_source.head(3)
# Out:
#                                               source  date_x
# 0          https://data36.com/learning-data-science/     151
# 1  https://data36.com/data-science-career-questio...      39
# 2                                https://data36.com/      27

# %% [markdown]
# # What converts JDS people

# %% [markdown]
# ### this is the tricky part -- creating last click attribution

# %%
#merging the visited pages to the macro conversion event
jds_converted_source = jds_converted.merge(pageviews, left_on = 'user_id1', right_on = 'user_id', how = 'inner')

# %%
#filtering for only those events that happened BEFORE the actual conversion
jds_converted_source = jds_converted_source[
    (jds_converted_source.time_x > jds_converted_source.time_y) & (
        jds_converted_source.date_x == jds_converted_source.date_y)]

# %%
#filtering for the LAST event before the conversion, remove duplicates, group, count, etc.
jds_converted_source = jds_converted_source[jds_converted_source.page == 'https://data36.com/the-junior-data-scientists-first-month-online-course/'
                  ].drop_duplicates('user_id1', keep='last').groupby('source').count()[['date_x']].sort_values(
    by='date_x', ascending = False)

# %%
#formatting
jds_converted_source = jds_converted_source.reset_index() #source

# %%
###this is the list of the last articles people visited before coming
###to the https://data36.com/how-to-become-a-data-scientist/ and actually subscribe.
jds_converted_source
# Out:
#                                                source  date_x
# 0                                 https://data36.com/      39
# 1           https://data36.com/learning-data-science/      26
# 2   https://data36.com/how-to-become-a-data-scient...      11
# 3   https://data36.com/sql-interview-questions-tec...       7
# 4   https://data36.com/data-science-career-questio...       7
# 5    https://data36.com/plot-histogram-python-pandas/       4
# 6   https://tomimester.medium.com/how-to-break-int...       4
# 7                     https://data36.com/tomi-mester/       4
# 8       https://data36.com/thank-you-for-subscribing/       4
# 9   https://data36.com/sql-data-analysis-advanced-...       4
# 10       https://data36.com/find-data-science-mentor/       3
# 11                           https://www.youtube.com/       3
# 12  https://data36.com/data36-inner-circle-subscri...       2
# 13                         https://data36.com/page/2/       2
# 14                https://data36.com/funnel-analysis/       2
# 15  https://data36.com/python-libraries-packages-d...       2
# 16  https://data36.com/python-for-data-science-pyt...       2
# 17  https://data36.com/best-computer-laptop-for-a-...       2
# 18  https://data36.com/data-coding-101-install-pyt...       2
# 19  https://data36.com/become-data-scientist-7-plu...       2
# 20  https://data36.com/pandas-tutorial-1-basics-re...       2
# 21  https://data36.com/get-job-data-science-analyt...       2
# 22           https://data36.com/what-is-data-science/       1
# 23                                https://mailchi.mp/       1
# 24    https://data36.com/computer-setup-data-science/       1
# 25                                      https://t.co/       1
# 26  https://tomimester.medium.com/aspiring-data-sc...       1
# 27  https://data36.com/beautiful-soup-tutorial-web...       1
# 28                            https://www.google.com/       1
# 29                          https://www.linkedin.com/       1
# 30  https://data36.com/sublime-text-data-science-r...       1
# 31  https://data36.com/statistical-significance-in...       1
# 32  https://data36.com/statistical-bias-types-expl...       1
# 33  https://data36.com/statistical-bias-types-exam...       1
# 34  https://data36.com/statistical-averages-mean-m...       1
# 35  https://data36.com/sql-best-practices-data-ana...       1
# 36  https://data36.com/sql-for-data-analysis-tutor...       1
# 37               https://data36.com/create-table-sql/       1
# 38  https://data36.com/sql-data-analysis-advanced-...       1
# 39  https://data36.com/scraping-multiple-web-pages...       1
# 40  https://data36.com/python-nested-loops-if-stat...       1
# 41  https://data36.com/python-for-data-science-and...       1
# 42  https://data36.com/pandas-tutorial-3-important...       1
# 43  https://data36.com/linear-regression-in-python...       1
# 44  https://data36.com/data-coding-101-introductio...       1
# 45  https://data36.com/learn-python-for-data-scien...       1
# 46  https://data36.com/learn-data-analytics-bash-s...       1
# 47  https://data36.com/install-sql-workbench-postg...       1
# 48  https://data36.com/how-to-import-data-into-sql...       1
# 49                https://data36.com/data-collection/       1
# 50               android-app://com.google.android.gm/       1

# %% [markdown]
# ### CREATING THE SUPER TABLE

# %%
howto_visited.head(3)
# Out:
#                                               source  date
# 0                                https://data36.com/   147
# 1  https://data36.com/become-data-scientist-7-plu...     7
# 2  https://data36.com/best-computer-laptop-for-a-...    73

# %%
howto_converted_source.head(3)
# Out:
#                                               source  date_x
# 0          https://data36.com/learning-data-science/     151
# 1  https://data36.com/data-science-career-questio...      39
# 2                                https://data36.com/      27

# %%
jds_visited.head(3)
# Out:
#                                               source  date
# 0                             http://m.facebook.com/    11
# 1                                https://data36.com/   516
# 2  https://data36.com/beautiful-soup-tutorial-web...     7

# %%
jds_converted_source.head(3)
# Out:
#                                               source  date_x
# 0                                https://data36.com/      39
# 1          https://data36.com/learning-data-science/      26
# 2  https://data36.com/how-to-become-a-data-scient...      11

# %%
#formatting the pageviews dataset, then counting the number of pageviews for each article
numb_of_pageviews = pageviews.drop_duplicates(subset=['user_id', 'page']).groupby('page').count()

#removing articles with less than 300 views -- and some formatting
numb_of_pageviews = numb_of_pageviews[numb_of_pageviews.date > 300].reset_index()[['page','date']] #page

# %%
######################
# MERGING EVERYTHING #
######################

super_table = numb_of_pageviews.merge(
    howto_visited, how='left', left_on = 'page', right_on = 'source').merge(
    howto_converted_source, how='left', left_on = 'page', right_on = 'source').merge(
    jds_visited, how='left', left_on = 'page', right_on = 'source').merge(
    jds_converted_source, how='left', left_on = 'page', right_on = 'source')

super_table = super_table[['page', 'date_x_x', 'date_y', 'date_x_y', 'date', 'date_x']]
super_table.columns = ['page', 'article_reads', 'howto_visited', 'howto_conv', 'jds_visited','jds_conv']

super_table = super_table.fillna(0)

# %%
super_table.sort_values(by = 'article_reads', ascending = False).to_csv('super_table.csv')

# %%
super_table.sort_values(by = 'howto_conv', ascending = False).head(10)
# Out:
#                                                  page  article_reads  \
# 33          https://data36.com/learning-data-science/           4384
# 10  https://data36.com/data-science-career-questio...           1628
# 0                                 https://data36.com/           4916
# 2   https://data36.com/best-computer-laptop-for-a-...           8878
# 59  https://data36.com/sql-interview-questions-tec...          14389
# 32  https://data36.com/learn-sql-for-data-analysis...           1363
# 14            https://data36.com/data-scientists-day/            330
# 70                    https://data36.com/tomi-mester/            435
# 65  https://data36.com/statistical-significance-in...           2350
# 49  https://data36.com/python-nested-loops-if-stat...          20802
#
#     howto_visited  howto_conv  jds_visited  jds_conv
# 33          521.0       151.0        175.0      26.0
# 10          130.0        39.0         47.0       7.0
# 0           147.0        27.0        516.0      39.0
# 2            73.0        13.0         28.0       2.0
# 59           53.0        12.0         58.0       7.0
# 32           21.0         7.0         15.0       0.0
# 14           13.0         6.0          6.0       0.0
# 70           31.0         6.0         49.0       4.0
# 65           23.0         5.0          9.0       1.0
# 49            6.0         4.0         17.0       1.0

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', -1)

super_table.sort_values(by = 'jds_conv', ascending = False).reset_index(drop= True)
# Out:
#                                                                                                      page  \
# 0   https://data36.com/
# 1   https://data36.com/learning-data-science/
# 2   https://data36.com/how-to-become-a-data-scientist-data36-inner-circle-subscription/
# 3   https://data36.com/data-science-career-question-1/
# 4   https://data36.com/sql-interview-questions-tech-screening-data-analysts/
# 5   https://data36.com/plot-histogram-python-pandas/
# 6   https://data36.com/sql-data-analysis-advanced-tutorial-ep6/
# 7   https://data36.com/tomi-mester/
# 8   https://data36.com/thank-you-for-subscribing/
# 9   https://data36.com/python-libraries-packages-data-scientists/
# 10  https://data36.com/best-computer-laptop-for-a-data-scientist/
# 11  https://data36.com/pandas-tutorial-1-basics-reading-data-files-dataframes-data-selection/
# 12  https://data36.com/python-for-data-science-python-basics-1/
# 13  https://data36.com/data36-inner-circle-subscription/
# 14  https://data36.com/funnel-analysis/
# 15  https://data36.com/data-coding-101-install-python-sql-r-bash/
# 16  https://data36.com/statistical-bias-types-explained/
# 17  https://data36.com/linear-regression-in-python-numpy-polyfit/
# 18  https://data36.com/beautiful-soup-tutorial-web-scraping/
# 19  https://data36.com/python-nested-loops-if-statements-combined-data-sciene/
# 20  https://data36.com/scraping-multiple-web-pages-urls-with-for-loops/
# 21  https://data36.com/sql-best-practices-data-analysts/
# 22  https://data36.com/learn-data-analytics-bash-scratch/
# 23  https://data36.com/sql-for-data-analysis-tutorial-beginners/
# 24  https://data36.com/sublime-text-data-science-remote-server/
# 25  https://data36.com/statistical-averages-mean-median-mode/
# 26  https://data36.com/statistical-significance-in-ab-testing/
# 27  https://data36.com/statistical-bias-types-examples-part2/
# 28  https://data36.com/learn-python-for-data-science-from-scratch/
# 29  https://data36.com/pandas-tutorial-3-important-data-formatting-methods-merge-sort-reset_index-fillna/
# 30  https://data36.com/what-is-data-science/
# 31  https://data36.com/data-coding-101-introduction-bash/
# 32  https://data36.com/install-sql-workbench-postgresql/
# 33  https://data36.com/how-to-import-data-into-sql-tables/
# 34  https://data36.com/computer-setup-data-science/
# 35  https://data36.com/create-table-sql/
# 36  https://data36.com/sql-for-aspiring-data-scientists-7-day-online-course/
# 37  https://data36.com/data-science-projects-for-boosting-your-resume/
# 38  https://data36.com/sql-functions-beginners-tutorial-ep3/
# 39  https://data36.com/data-science-freelancing-tips/
# 40  https://data36.com/sql-join-data-analysis-tutorial-ep5/
# 41  https://data36.com/sql-where-clause-tutorial-beginners-ep2/
# 42  https://data36.com/data-science-cv-resume-cover-letter-github/
# 43  https://data36.com/statistical-variability-standard-deviation-percentiles-histogram/
# 44  https://data36.com/data-analytics-basics-intro/
# 45  https://data36.com/sql-current-date-time/
# 46  https://data36.com/connect-google-data-studio-postgresql/
# 47  https://data36.com/the-junior-data-scientists-first-month-online-course/
# 48  https://data36.com/bevezetes-data-science-vilagaba/
# 49  https://data36.com/upload-dataset-to-a-server-command-line-jupyter/
# 50  https://data36.com/variables-if-statements-while-loops-bash-data-science/
# 51  https://data36.com/web-scraping-tutorial-episode-1-scraping-a-webpage-with-bash/
# 52  https://data36.com/data-scientists-day/
# 53  https://data36.com/kevin-bacon-game-recursive-sql/
# 54  https://data36.com/data-team-structure-data-organization/
# 55  https://data36.com/python-built-in-functions-methods-python-data-science-basics-3/
# 56  https://data36.com/learn-sql-for-data-analysis-from-scratch/
# 57  https://data36.com/inner-circle-data36-newsletter-free-data-science-resources/
# 58  https://data36.com/how-to-run-python-script/
# 59  https://data36.com/pandas-tutorial-2-aggregation-and-grouping/
# 60  https://data36.com/how-to-become-a-data-scientist/
# 61  https://data36.com/predictive-analytics-101-part-1/
# 62  https://data36.com/predictive-analytics-101-part-2/
# 63  https://data36.com/presentation-tips-for-data-professionals/
# 64  https://data36.com/python-data-structures-data-science-basics/
# 65  https://data36.com/junior-data-scientist-akademia/
# 66  https://data36.com/google-analytics-reports-top/
# 67  https://data36.com/python-for-loops-explained-data-science-basics-5/
# 68  https://data36.com/python-if-statements-explained-data-science-basics/
# 69  https://data36.com/python-import-built-in-modules-data-science/
# 70  https://data36.com/five-second-testing/
# 71  https://data36.com/fake-door-testing/
# 72  https://data36.com/python-syntax-essentials-and-best-practices/
# 73  https://data36.com/scatter-plot-pandas-matplotlib/
# 74  https://data36.com/expected-value-formula/
#
#     article_reads  howto_visited  howto_conv  jds_visited  jds_conv
# 0   4916           147.0          27.0        516.0        39.0
# 1   4384           521.0          151.0       175.0        26.0
# 2   417            25.0           0.0         24.0         11.0
# 3   1628           130.0          39.0        47.0         7.0
# 4   14389          53.0           12.0        58.0         7.0
# 5   18761          15.0           4.0         21.0         4.0
# 6   529            0.0            3.0         12.0         4.0
# 7   435            31.0           6.0         49.0         4.0
# 8   749            20.0           2.0         32.0         4.0
# 9   2914           14.0           3.0         13.0         2.0
# 10  8878           73.0           13.0        28.0         2.0
# 11  9081           15.0           4.0         45.0         2.0
# 12  921            13.0           2.0         16.0         2.0
# 13  303            0.0            1.0         15.0         2.0
# 14  1032           0.0            0.0         12.0         2.0
# 15  1767           18.0           1.0         16.0         2.0
# 16  9660           11.0           0.0         14.0         1.0
# 17  9726           14.0           4.0         15.0         1.0
# 18  422            0.0            0.0         7.0          1.0
# 19  20802          6.0            4.0         17.0         1.0
# 20  2153           0.0            0.0         0.0          1.0
# 21  1435           0.0            1.0         0.0          1.0
# 22  565            7.0            0.0         7.0          1.0
# 23  1336           14.0           2.0         20.0         1.0
# 24  2100           0.0            0.0         0.0          1.0
# 25  3265           10.0           1.0         12.0         1.0
# 26  2350           23.0           5.0         9.0          1.0
# 27  3847           13.0           3.0         9.0          1.0
# 28  1000           15.0           4.0         15.0         1.0
# 29  798            0.0            0.0         79.0         1.0
# 30  806            11.0           4.0         6.0          1.0
# 31  327            0.0            0.0         0.0          1.0
# 32  3275           0.0            0.0         0.0          1.0
# 33  12440          6.0            1.0         6.0          1.0
# 34  873            9.0            4.0         10.0         1.0
# 35  9091           0.0            0.0         0.0          1.0
# 36  1007           0.0            0.0         0.0          0.0
# 37  618            0.0            0.0         0.0          0.0
# 38  10633          0.0            0.0         0.0          0.0
# 39  476            18.0           3.0         7.0          0.0
# 40  327            0.0            0.0         0.0          0.0
# 41  382            0.0            0.0         0.0          0.0
# 42  368            0.0            0.0         0.0          0.0
# 43  448            0.0            0.0         0.0          0.0
# 44  316            12.0           2.0         6.0          0.0
# 45  6853           0.0            0.0         0.0          0.0
# 46  799            0.0            1.0         0.0          0.0
# 47  2549           0.0            0.0         0.0          0.0
# 48  338            0.0            0.0         0.0          0.0
# 49  566            0.0            0.0         0.0          0.0
# 50  1671           0.0            0.0         0.0          0.0
# 51  1517           0.0            0.0         6.0          0.0
# 52  330            13.0           6.0         6.0          0.0
# 53  323            0.0            0.0         0.0          0.0
# 54  638            0.0            1.0         0.0          0.0
# 55  6269           17.0           2.0         15.0         0.0
# 56  1363           21.0           7.0         15.0         0.0
# 57  862            0.0            0.0         0.0          0.0
# 58  984            0.0            0.0         0.0          0.0
# 59  15085          16.0           3.0         15.0         0.0
# 60  1736           0.0            0.0         0.0          0.0
# 61  601            0.0            1.0         0.0          0.0
# 62  604            0.0            0.0         11.0         0.0
# 63  495            6.0            0.0         0.0          0.0
# 64  509            0.0            0.0         0.0          0.0
# 65  590            0.0            0.0         0.0          0.0
# 66  349            0.0            1.0         0.0          0.0
# 67  2100           11.0           1.0         7.0          0.0
# 68  2250           0.0            1.0         0.0          0.0
# 69  384            0.0            0.0         0.0          0.0
# 70  498            0.0            0.0         0.0          0.0
# 71  817            0.0            2.0         0.0          0.0
# 72  406            0.0            0.0         0.0          0.0
# 73  8479           12.0           2.0         23.0         0.0
# 74  1574           0.0            0.0         0.0          0.0

# %% [markdown]
# # 5. What people do before they subscribe to JDS

# %%
#let's see hypothesis #2!

# %% [markdown]
# ### how many articles people read before they subscribe to JDS

# %%
#jds conversions
jds_converted_before = jds[jds.button == "Subscribe!"][['user_id1', 'date', 'time']].drop_duplicates('user_id1')

# %%
#merging the visited pages to the macro conversion event
jds_converted_before = jds_converted_before.merge(
    pageviews, left_on = 'user_id1', right_on = 'user_id', how = 'inner')

# %%
#filtering for only those events that happened BEFORE the actual conversion
jds_converted_before = jds_converted_before[(
    jds_converted_before.time_x > jds_converted_before.time_y) & (
        jds_converted_before.date_x >= jds_converted_before.date_y)]

# %%
#formatting, counting, then counting again (How many articles people read before convert)
jds_converted_before.reset_index().groupby('user_id1').count().groupby('index').date_x.count().head(3)
# Out:
# index
# 1    40
# 2    68
# 3    24
# Name: date_x, dtype: int64

# %%
jds_converted_before.reset_index().groupby('user_id1').count().groupby('index').date_x.count().plot.bar()

# %% [markdown]
# # 6. What people do before they subscribe to JDS -- for specific articles

# %%
spec_article = 'https://data36.com/learning-data-science/'

converted_read_spec_art = jds_converted_before[jds_converted_before.page == spec_article][['user_id1']].drop_duplicates()
print(spec_article)

converted_read_spec_art.merge(
    jds_converted_before, how = 'inner').reset_index(
    ).groupby('user_id1').count().groupby('index').count()[['date_x']].plot.bar()
# Out:
# https://data36.com/learning-data-science/

# %%
spec_article = 'https://data36.com/data-science-career-question-1/'

converted_read_spec_art = jds_converted_before[jds_converted_before.page == spec_article][['user_id1']].drop_duplicates()
print(spec_article)

converted_read_spec_art.merge(
    jds_converted_before, how = 'inner').reset_index(
    ).groupby('user_id1').count().groupby('index').count()[['date_x']].plot.bar()
# Out:
# https://data36.com/data-science-career-question-1/

# %%
spec_article = 'https://data36.com/'

converted_read_spec_art = jds_converted_before[jds_converted_before.page == spec_article][['user_id1']].drop_duplicates()
print(spec_article)

converted_read_spec_art.merge(
    jds_converted_before, how = 'inner').reset_index(
    ).groupby('user_id1').count().groupby('index').count()[['date_x']].plot.bar()
# Out:
# https://data36.com/
